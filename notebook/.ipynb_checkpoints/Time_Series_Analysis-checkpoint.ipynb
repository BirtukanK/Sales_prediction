# %%
import os
import sys
import dvc.api
import pandas as pd
import matplotlib as plt

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import logging
import numpy as np

# %%
data_file = 'store_train_data.csv'

# the local data path
local_path = '../sales-data/' + data_file

# the path to the data set
path = 'sales-data/' + data_file

# base repository
repo = '../'

# %%
version = 'v1'

# data path using dvc api
data_url = dvc.api.get_url(path = path, repo = repo, rev = version)

# reading the csv file
missing_values = ["n/a", "na", "undefined", '?', 'NA', 'undefined']
df = pd.read_csv(data_url, na_values=missing_values)
df
# Out:
#          Unnamed: 0  Store StoreType Assortment  CompetitionDistance  \
# 0                 0      1         c          a               1270.0
# 1                 1      1         c          a               1270.0
# 2                 2      1         c          a               1270.0
# 3                 3      1         c          a               1270.0
# 4                 4      1         c          a               1270.0
# ...             ...    ...       ...        ...                  ...
# 1017204     1017204   1115         d          c               5350.0
# 1017205     1017205   1115         d          c               5350.0
# 1017206     1017206   1115         d          c               5350.0
# 1017207     1017207   1115         d          c               5350.0
# 1017208     1017208   1115         d          c               5350.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                              9.0                    2008.0       0
# 2                              9.0                    2008.0       0
# 3                              9.0                    2008.0       0
# 4                              9.0                    2008.0       0
# ...                            ...                       ...     ...
# 1017204                        NaN                       NaN       1
# 1017205                        NaN                       NaN       1
# 1017206                        NaN                       NaN       1
# 1017207                        NaN                       NaN       1
# 1017208                        NaN                       NaN       1
#
#          Promo2SinceWeek  Promo2SinceYear     PromoInterval  DayOfWeek  \
# 0                    NaN              NaN               NaN          5
# 1                    NaN              NaN               NaN          4
# 2                    NaN              NaN               NaN          3
# 3                    NaN              NaN               NaN          2
# 4                    NaN              NaN               NaN          1
# ...                  ...              ...               ...        ...
# 1017204             22.0           2012.0  Mar,Jun,Sept,Dec          6
# 1017205             22.0           2012.0  Mar,Jun,Sept,Dec          5
# 1017206             22.0           2012.0  Mar,Jun,Sept,Dec          4
# 1017207             22.0           2012.0  Mar,Jun,Sept,Dec          3
# 1017208             22.0           2012.0  Mar,Jun,Sept,Dec          2
#
#                Date  Sales  Customers  Open  Promo StateHoliday  SchoolHoliday
# 0        2015-07-31   5263        555     1      1            0              1
# 1        2015-07-30   5020        546     1      1            0              1
# 2        2015-07-29   4782        523     1      1            0              1
# 3        2015-07-28   5011        560     1      1            0              1
# 4        2015-07-27   6102        612     1      1            0              1
# ...             ...    ...        ...   ...    ...          ...            ...
# 1017204  2013-01-05   4771        339     1      0            0              1
# 1017205  2013-01-04   4540        326     1      0            0              1
# 1017206  2013-01-03   4297        300     1      0            0              1
# 1017207  2013-01-02   3697        305     1      0            0              1
# 1017208  2013-01-01      0          0     0      0            a              1
#
# [1017209 rows x 19 columns]

# %%
df['Store'].nunique()
# Out:
# 1115

# %%
df['Store'].unique()
# Out:
# array([   1,    2,    3, ..., 1113, 1114, 1115], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Unnamed: 0                 1017209 non-null  int64
#  1   Store                      1017209 non-null  int64
#  2   StoreType                  1017209 non-null  object
#  3   Assortment                 1017209 non-null  object
#  4   CompetitionDistance        1014567 non-null  float64
#  5   CompetitionOpenSinceMonth  693861 non-null   float64
#  6   CompetitionOpenSinceYear   693861 non-null   float64
#  7   Promo2                     1017209 non-null  int64
#  8   Promo2SinceWeek            509178 non-null   float64
#  9   Promo2SinceYear            509178 non-null   float64
#  10  PromoInterval              509178 non-null   object
#  11  DayOfWeek                  1017209 non-null  int64
#  12  Date                       1017209 non-null  object
#  13  Sales                      1017209 non-null  int64
#  14  Customers                  1017209 non-null  int64
#  15  Open                       1017209 non-null  int64
#  16  Promo                      1017209 non-null  int64
#  17  StateHoliday               1017209 non-null  object
#  18  SchoolHoliday              1017209 non-null  int64
# dtypes: float64(5), int64(9), object(5)
# memory usage: 147.5+ MB

# %%
df['Unnamed: 0'].nunique()
# Out:
# 1017209

# %%
#we drop the Unnamed: 0 column since it has no functionality.
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.sample(2)
# Out:
#         Store StoreType Assortment  CompetitionDistance  \
# 352405    387         c          a                210.0
# 342146    376         a          a                160.0
#
#         CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 352405                        NaN                       NaN       1
# 342146                        8.0                    2012.0       0
#
#         Promo2SinceWeek  Promo2SinceYear     PromoInterval  DayOfWeek  \
# 352405             36.0           2013.0  Mar,Jun,Sept,Dec          7
# 342146              NaN              NaN               NaN          4
#
#               Date  Sales  Customers  Open  Promo StateHoliday  SchoolHoliday
# 352405  2015-01-11      0          0     0      0            0              0
# 342146  2015-04-02  13526       1285     1      1            0              1

# %%
df.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      1         c          a               1270.0                        9.0
# 2      1         c          a               1270.0                        9.0
# 3      1         c          a               1270.0                        9.0
# 4      1         c          a               1270.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2008.0       0              NaN              NaN
# 2                    2008.0       0              NaN              NaN
# 3                    2008.0       0              NaN              NaN
# 4                    2008.0       0              NaN              NaN
#
#   PromoInterval  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0           NaN          5  2015-07-31   5263        555     1      1
# 1           NaN          4  2015-07-30   5020        546     1      1
# 2           NaN          3  2015-07-29   4782        523     1      1
# 3           NaN          2  2015-07-28   5011        560     1      1
# 4           NaN          1  2015-07-27   6102        612     1      1
#
#   StateHoliday  SchoolHoliday
# 0            0              1
# 1            0              1
# 2            0              1
# 3            0              1
# 4            0              1

# %% [markdown]
# Data preprocessing

# %% [markdown]
# After we merge our store and train files together in a dataframe then we start to look for the outliers and missing values.

# %%
print(f'shape: {df.shape}, size: {df.size}')
# Out:
# shape: (1017209, 18), size: 18309762

# %%
df.duplicated().value_counts()
# Out:
# False    1017209
# dtype: int64

# %%
df.isna().sum()
# Out:
# Store                             0
# StoreType                         0
# Assortment                        0
# CompetitionDistance            2642
# CompetitionOpenSinceMonth    323348
# CompetitionOpenSinceYear     323348
# Promo2                            0
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# PromoInterval                508031
# DayOfWeek                         0
# Date                              0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# dtype: int64

# %% [markdown]
# As we can see we have values which, are replaced by boolean value of True on CompetitionDistance, CompetitionOpenSinceMonth,
# CompetitionOpenSinceYear, Promo2SinceWeek, Promo2SinceYear, PromoInterval columns.

# %%
df.isnull().any()
# Out:
# Store                        False
# StoreType                    False
# Assortment                   False
# CompetitionDistance           True
# CompetitionOpenSinceMonth     True
# CompetitionOpenSinceYear      True
# Promo2                       False
# Promo2SinceWeek               True
# Promo2SinceYear               True
# PromoInterval                 True
# DayOfWeek                    False
# Date                         False
# Sales                        False
# Customers                    False
# Open                         False
# Promo                        False
# StateHoliday                 False
# SchoolHoliday                False
# dtype: bool

# %%
print(df['Date'])
# Out:
# 0          2015-07-31
# 1          2015-07-30
# 2          2015-07-29
# 3          2015-07-28
# 4          2015-07-27
#               ...
# 1017204    2013-01-05
# 1017205    2013-01-04
# 1017206    2013-01-03
# 1017207    2013-01-02
# 1017208    2013-01-01
# Name: Date, Length: 1017209, dtype: object

# %%
# separate the Date column to year, month, and day
df[['year', 'month', 'day']] = df['Date'].str.split('-', expand=True)
# display the dataframe
df
# Out:
#          Store StoreType Assortment  CompetitionDistance  \
# 0            1         c          a               1270.0
# 1            1         c          a               1270.0
# 2            1         c          a               1270.0
# 3            1         c          a               1270.0
# 4            1         c          a               1270.0
# ...        ...       ...        ...                  ...
# 1017204   1115         d          c               5350.0
# 1017205   1115         d          c               5350.0
# 1017206   1115         d          c               5350.0
# 1017207   1115         d          c               5350.0
# 1017208   1115         d          c               5350.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                              9.0                    2008.0       0
# 2                              9.0                    2008.0       0
# 3                              9.0                    2008.0       0
# 4                              9.0                    2008.0       0
# ...                            ...                       ...     ...
# 1017204                        NaN                       NaN       1
# 1017205                        NaN                       NaN       1
# 1017206                        NaN                       NaN       1
# 1017207                        NaN                       NaN       1
# 1017208                        NaN                       NaN       1
#
#          Promo2SinceWeek  Promo2SinceYear     PromoInterval  ...        Date  \
# 0                    NaN              NaN               NaN  ...  2015-07-31
# 1                    NaN              NaN               NaN  ...  2015-07-30
# 2                    NaN              NaN               NaN  ...  2015-07-29
# 3                    NaN              NaN               NaN  ...  2015-07-28
# 4                    NaN              NaN               NaN  ...  2015-07-27
# ...                  ...              ...               ...  ...         ...
# 1017204             22.0           2012.0  Mar,Jun,Sept,Dec  ...  2013-01-05
# 1017205             22.0           2012.0  Mar,Jun,Sept,Dec  ...  2013-01-04
# 1017206             22.0           2012.0  Mar,Jun,Sept,Dec  ...  2013-01-03
# 1017207             22.0           2012.0  Mar,Jun,Sept,Dec  ...  2013-01-02
# 1017208             22.0           2012.0  Mar,Jun,Sept,Dec  ...  2013-01-01
#
#         Sales  Customers  Open  Promo  StateHoliday SchoolHoliday  year month  \
# 0        5263        555     1      1             0             1  2015    07
# 1        5020        546     1      1             0             1  2015    07
# 2        4782        523     1      1             0             1  2015    07
# 3        5011        560     1      1             0             1  2015    07
# 4        6102        612     1      1             0             1  2015    07
# ...       ...        ...   ...    ...           ...           ...   ...   ...
# 1017204  4771        339     1      0             0             1  2013    01
# 1017205  4540        326     1      0             0             1  2013    01
# 1017206  4297        300     1      0             0             1  2013    01
# 1017207  3697        305     1      0             0             1  2013    01
# 1017208     0          0     0      0             a             1  2013    01
#
#         day
# 0        31
# 1        30
# 2        29
# 3        28
# 4        27
# ...      ..
# 1017204  05
# 1017205  04
# 1017206  03
# 1017207  02
# 1017208  01
#
# [1017209 rows x 21 columns]

# %%
sales_df = df['Sales']
sales_df.head()
# Out:
# 0    5263
# 1    5020
# 2    4782
# 3    5011
# 4    6102
# Name: Sales, dtype: int64

# %%
sales_df.plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
df['Promo2SinceWeek'] = df['Promo2SinceWeek'].bfill()

# %%
df['Promo2SinceYear'] = df['Promo2SinceYear'].bfill()

# %%
df['PromoInterval'] = df['PromoInterval'].bfill()

# %%
df.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      1         c          a               1270.0                        9.0
# 2      1         c          a               1270.0                        9.0
# 3      1         c          a               1270.0                        9.0
# 4      1         c          a               1270.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0             13.0           2010.0
# 1                    2008.0       0             13.0           2010.0
# 2                    2008.0       0             13.0           2010.0
# 3                    2008.0       0             13.0           2010.0
# 4                    2008.0       0             13.0           2010.0
#
#      PromoInterval  ...        Date Sales  Customers  Open  Promo  \
# 0  Jan,Apr,Jul,Oct  ...  2015-07-31  5263        555     1      1
# 1  Jan,Apr,Jul,Oct  ...  2015-07-30  5020        546     1      1
# 2  Jan,Apr,Jul,Oct  ...  2015-07-29  4782        523     1      1
# 3  Jan,Apr,Jul,Oct  ...  2015-07-28  5011        560     1      1
# 4  Jan,Apr,Jul,Oct  ...  2015-07-27  6102        612     1      1
#
#    StateHoliday SchoolHoliday  year month day
# 0             0             1  2015    07  31
# 1             0             1  2015    07  30
# 2             0             1  2015    07  29
# 3             0             1  2015    07  28
# 4             0             1  2015    07  27
#
# [5 rows x 21 columns]

# %%
date_df = df.set_index('Date', inplace=False)
date_df
# Out:
#             Store StoreType Assortment  CompetitionDistance  \
# Date
# 2015-07-31      1         c          a               1270.0
# 2015-07-30      1         c          a               1270.0
# 2015-07-29      1         c          a               1270.0
# 2015-07-28      1         c          a               1270.0
# 2015-07-27      1         c          a               1270.0
# ...           ...       ...        ...                  ...
# 2013-01-05   1115         d          c               5350.0
# 2013-01-04   1115         d          c               5350.0
# 2013-01-03   1115         d          c               5350.0
# 2013-01-02   1115         d          c               5350.0
# 2013-01-01   1115         d          c               5350.0
#
#             CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# Date
# 2015-07-31                        9.0                    2008.0       0
# 2015-07-30                        9.0                    2008.0       0
# 2015-07-29                        9.0                    2008.0       0
# 2015-07-28                        9.0                    2008.0       0
# 2015-07-27                        9.0                    2008.0       0
# ...                               ...                       ...     ...
# 2013-01-05                        NaN                       NaN       1
# 2013-01-04                        NaN                       NaN       1
# 2013-01-03                        NaN                       NaN       1
# 2013-01-02                        NaN                       NaN       1
# 2013-01-01                        NaN                       NaN       1
#
#             Promo2SinceWeek  Promo2SinceYear     PromoInterval  DayOfWeek  \
# Date
# 2015-07-31             13.0           2010.0   Jan,Apr,Jul,Oct          5
# 2015-07-30             13.0           2010.0   Jan,Apr,Jul,Oct          4
# 2015-07-29             13.0           2010.0   Jan,Apr,Jul,Oct          3
# 2015-07-28             13.0           2010.0   Jan,Apr,Jul,Oct          2
# 2015-07-27             13.0           2010.0   Jan,Apr,Jul,Oct          1
# ...                     ...              ...               ...        ...
# 2013-01-05             22.0           2012.0  Mar,Jun,Sept,Dec          6
# 2013-01-04             22.0           2012.0  Mar,Jun,Sept,Dec          5
# 2013-01-03             22.0           2012.0  Mar,Jun,Sept,Dec          4
# 2013-01-02             22.0           2012.0  Mar,Jun,Sept,Dec          3
# 2013-01-01             22.0           2012.0  Mar,Jun,Sept,Dec          2
#
#             Sales  Customers  Open  Promo StateHoliday  SchoolHoliday  year  \
# Date
# 2015-07-31   5263        555     1      1            0              1  2015
# 2015-07-30   5020        546     1      1            0              1  2015
# 2015-07-29   4782        523     1      1            0              1  2015
# 2015-07-28   5011        560     1      1            0              1  2015
# 2015-07-27   6102        612     1      1            0              1  2015
# ...           ...        ...   ...    ...          ...            ...   ...
# 2013-01-05   4771        339     1      0            0              1  2013
# 2013-01-04   4540        326     1      0            0              1  2013
# 2013-01-03   4297        300     1      0            0              1  2013
# 2013-01-02   3697        305     1      0            0              1  2013
# 2013-01-01      0          0     0      0            a              1  2013
#
#            month day
# Date
# 2015-07-31    07  31
# 2015-07-30    07  30
# 2015-07-29    07  29
# 2015-07-28    07  28
# 2015-07-27    07  27
# ...          ...  ..
# 2013-01-05    01  05
# 2013-01-04    01  04
# 2013-01-03    01  03
# 2013-01-02    01  02
# 2013-01-01    01  01
#
# [1017209 rows x 20 columns]

# %%
df['CompetitionOpenSinceMonth'] = df['CompetitionOpenSinceMonth'].ffill()
df['CompetitionOpenSinceYear'] = df['CompetitionOpenSinceYear'].ffill()

# %% [markdown]
# filling missing values of CompetitionOpenSinceMonth and CompetitionOpenSinceYear using ffill method

# %%
df.describe()
# Out:
#               Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1.017209e+06            1017209.0               1.017209e+06
# mean   5.584297e+02                 20.0               7.109156e+00
# std    3.219087e+02                  0.0               3.179178e+00
# min    1.000000e+00                 20.0               1.000000e+00
# 25%    2.800000e+02                 20.0               4.000000e+00
# 50%    5.580000e+02                 20.0               7.000000e+00
# 75%    8.380000e+02                 20.0               1.000000e+01
# max    1.115000e+03                 20.0               1.200000e+01
#
#        CompetitionOpenSinceYear        Promo2  Promo2SinceWeek  \
# count              1.017209e+06  1.017209e+06     1.017209e+06
# mean               2.008763e+03  5.005638e-01     2.400359e+01
# std                5.826298e+00  4.999999e-01     1.410868e+01
# min                1.900000e+03  0.000000e+00     1.000000e+00
# 25%                2.006000e+03  0.000000e+00     1.300000e+01
# 50%                2.010000e+03  1.000000e+00     2.200000e+01
# 75%                2.013000e+03  1.000000e+00     3.700000e+01
# max                2.015000e+03  1.000000e+00     5.000000e+01
#
#        Promo2SinceYear     DayOfWeek         Sales     Customers  \
# count     1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean      2.011749e+03  3.998341e+00  5.773819e+03  6.331459e+02
# std       1.684496e+00  1.997391e+00  3.849926e+03  4.644117e+02
# min       2.009000e+03  1.000000e+00  0.000000e+00  0.000000e+00
# 25%       2.011000e+03  2.000000e+00  3.727000e+03  4.050000e+02
# 50%       2.012000e+03  4.000000e+00  5.744000e+03  6.090000e+02
# 75%       2.013000e+03  6.000000e+00  7.856000e+03  8.370000e+02
# max       2.015000e+03  7.000000e+00  4.155100e+04  7.388000e+03
#
#                Open         Promo  SchoolHoliday
# count  1.017209e+06  1.017209e+06   1.017209e+06
# mean   8.301067e-01  3.815145e-01   1.786467e-01
# std    3.755392e-01  4.857586e-01   3.830564e-01
# min    0.000000e+00  0.000000e+00   0.000000e+00
# 25%    1.000000e+00  0.000000e+00   0.000000e+00
# 50%    1.000000e+00  0.000000e+00   0.000000e+00
# 75%    1.000000e+00  1.000000e+00   0.000000e+00
# max    1.000000e+00  1.000000e+00   1.000000e+00

# %% [markdown]
# filling the missing value of CompetitionDistance using it min value

# %%
df['CompetitionDistance'] = df['CompetitionDistance'].min()

# %%
date_df.head()
# Out:
#             Store StoreType Assortment  CompetitionDistance  \
# Date
# 2015-07-31      1         c          a               1270.0
# 2015-07-30      1         c          a               1270.0
# 2015-07-29      1         c          a               1270.0
# 2015-07-28      1         c          a               1270.0
# 2015-07-27      1         c          a               1270.0
#
#             CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# Date
# 2015-07-31                        9.0                    2008.0       0
# 2015-07-30                        9.0                    2008.0       0
# 2015-07-29                        9.0                    2008.0       0
# 2015-07-28                        9.0                    2008.0       0
# 2015-07-27                        9.0                    2008.0       0
#
#             Promo2SinceWeek  Promo2SinceYear    PromoInterval  DayOfWeek  \
# Date
# 2015-07-31             13.0           2010.0  Jan,Apr,Jul,Oct          5
# 2015-07-30             13.0           2010.0  Jan,Apr,Jul,Oct          4
# 2015-07-29             13.0           2010.0  Jan,Apr,Jul,Oct          3
# 2015-07-28             13.0           2010.0  Jan,Apr,Jul,Oct          2
# 2015-07-27             13.0           2010.0  Jan,Apr,Jul,Oct          1
#
#             Sales  Customers  Open  Promo StateHoliday  SchoolHoliday  year  \
# Date
# 2015-07-31   5263        555     1      1            0              1  2015
# 2015-07-30   5020        546     1      1            0              1  2015
# 2015-07-29   4782        523     1      1            0              1  2015
# 2015-07-28   5011        560     1      1            0              1  2015
# 2015-07-27   6102        612     1      1            0              1  2015
#
#            month day
# Date
# 2015-07-31    07  31
# 2015-07-30    07  30
# 2015-07-29    07  29
# 2015-07-28    07  28
# 2015-07-27    07  27

# %%
df.isnull().any()
# Out:
# Store                        False
# StoreType                    False
# Assortment                   False
# CompetitionDistance          False
# CompetitionOpenSinceMonth    False
# CompetitionOpenSinceYear     False
# Promo2                       False
# Promo2SinceWeek              False
# Promo2SinceYear              False
# PromoInterval                False
# DayOfWeek                    False
# Date                         False
# Sales                        False
# Customers                    False
# Open                         False
# Promo                        False
# StateHoliday                 False
# SchoolHoliday                False
# year                         False
# month                        False
# day                          False
# dtype: bool

# %% [markdown]
# Now we have no missing value in our data set.

# %%
test_df = pd.read_csv('../data/test.csv')

# %%
test_df.drop(['Id'], axis=1, inplace=True)

# %%
test_df.head()
# Out:
#    Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0      1          4  2015-09-17   1.0      1            0              0
# 1      3          4  2015-09-17   1.0      1            0              0
# 2      7          4  2015-09-17   1.0      1            0              0
# 3      8          4  2015-09-17   1.0      1            0              0
# 4      9          4  2015-09-17   1.0      1            0              0

# %%
test_df.head()
# Out:
#    Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0      1          4  2015-09-17   1.0      1            0              0
# 1      3          4  2015-09-17   1.0      1            0              0
# 2      7          4  2015-09-17   1.0      1            0              0
# 3      8          4  2015-09-17   1.0      1            0              0
# 4      9          4  2015-09-17   1.0      1            0              0

# %%
test_df['Open'] = test_df['Open'].max()

# %%
test_df.isnull().any()
# Out:
# Store            False
# DayOfWeek        False
# Date             False
# Open             False
# Promo            False
# StateHoliday     False
# SchoolHoliday    False
# dtype: bool

# %%
result = df.head(20)

# %%
train_df = pd.read_csv('../data/train.csv')
# Out:
# C:\Users\ACF\AppData\Local\Temp\ipykernel_3028\3604097393.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv('../data/train.csv')

# %%
train_df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
train_df.isnull().any()
# Out:
# Store            False
# DayOfWeek        False
# Date             False
# Sales            False
# Customers        False
# Open             False
# Promo            False
# StateHoliday     False
# SchoolHoliday    False
# dtype: bool

# %% [markdown]
# EDA

# %% [markdown]
# After performing the data preprocessing then we perform the Exploratory data analysis
